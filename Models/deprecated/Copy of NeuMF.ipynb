# %%
# Mount your google drive in google colab
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.insert(0,'/content/drive/MyDrive/CS247/Models')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from util import *
from model import MLPEmbedding
from model import GMF
from evaluate import *
import torch
import torch.nn as nn
from torch import optim

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
train_data = pd.read_pickle("/content/drive/MyDrive/CS247/Data/train_data.pkl")
val_data = pd.read_pickle("/content/drive/MyDrive/CS247/Data/val_data.pkl")
test_data = pd.read_pickle("/content/drive/MyDrive/CS247/Data/test_data.pkl")[['review_profilename','beer_name','review_overall']]
test_data = merge_user_id(test_data, on='review_profilename').rename(columns={'id':'user_id'})
test_data = merge_beer_id(test_data, on='beer_name').rename(columns={'id':'beer_id'})[['user_id','beer_id','review_overall']]

# %%
# convert review score to boolean - if the item is relevant to the user (rating >= 3.5) then 1, else 0
threshold = 4.0
train_data['relevant'] = (train_data['review_overall'] >= threshold).astype(int)
train_data.head()
# Out:
#         user_id  beer_id  review_overall  relevant
# 383941      415      831             3.5         0
# 483700     2492     3491             4.0         1
# 375376     1233     1178             4.5         1
# 705138     1230      902             4.5         1
# 435972     2290     7497             3.5         0

# %%
### unique users & beers in train_data
n_users = len(train_data['user_id'].unique())
n_beers = len(train_data['beer_id'].unique())
print("unique users: ", n_users)
print("unique beers: ", n_beers)
# Out:
# unique users:  14811
# unique beers:  52583

# %%
class NeuMF(nn.Module):
  def __init__(self, gmf_model, mlp_model, n_input, device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu")):
    ## n_input = sum of output shape of the last layer of gmf and mlp model
    super().__init__()
    self.gmf_model=gmf_model
    self.mlp_model=mlp_model
    self.net = nn.Linear(n_input, 1) ## we can add more layers here
    self.device = device
  
  def forward(self, df):
    # df: user_id, beer_id
    mlp_out = self.mlp_model.forward(df) # (n,25)
    ## TODO: output of the gmf_model
    gmf_out = self.gmf_model.forward_no_h(df)
    input = torch.cat((mlp_out, gmf_out), axis=1).to(self.device)
    return self.net(input)

  def predict(self, df):
    return torch.sigmoid(self.forward(df))

  def loss(self, df, loss_fn):
    y_pred = self.forward(df).view(-1)
    y_train = torch.Tensor(df.relevant.to_numpy()).to(self.device)
    
    return loss_fn(y_pred, y_train)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
n_hidden = 150
epochs = 40
batch_size = 500
lr = 0.01
loss_fn = nn.BCEWithLogitsLoss()
label_pred = 'pred_y'
k=5

# %%
# https://discuss.pytorch.org/t/merging-two-models/45637
gmf_model =  GMF(n_users,n_beers)
gmf_model.load_state_dict(torch.load("/content/drive/MyDrive/CS247/Models/checkpoints/gmf.pth"))
gmf_model.to(device)
mlp_model = MLPEmbedding(n_users=n_users, n_beers=n_beers, device=device, hidden_size=150).to(device)
mlp_model.load_state_dict(torch.load("/content/drive/MyDrive/CS247/Models/checkpoints/mlp_best.pth")['model_state_dict'])
# neu_mf_model = NeuMF(gmf_model, mlp_model, n_input, device)
# optimizer = optim.Adam(list(neu_mf_model.gmf_model.parameters()) + list(neu_mf_model.mlp_model.parameters()) + list(neu_mf_model.net.parameters()), lr=1e-4, weight_decay=5e-4)
# Out:
# <All keys matched successfully>

# %%
## TODO: train the model using train_data and validate against val_data
import math

# device = gpu
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
## model params
mlp_hidden_size = 150
gmf_hidden_size = 5
epochs = 80
batch_size = 256
lr = 1e-3
loss_fn = nn.BCEWithLogitsLoss()
label_pred = 'pred_y'
alpha=0.5
k=5

# n_users, n_beers, mlp_hidden_size, gmf_hidden_size, device
neu_mf = NeuMF(gmf_model=gmf_model, mlp_model=mlp_model, n_input=30, device=device).to(device)

optimizer = optim.Adam(list(neu_mf.gmf_model.parameters()) + list(neu_mf.mlp_model.parameters()) + list(neu_mf.net.parameters()), lr=lr, weight_decay=5e-4)
#scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, [15,60], gamma=0.1)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3, threshold=0.001, threshold_mode='rel', cooldown=0, min_lr=1e-5, eps=1e-08, verbose=True)
l = []
val_p = []
train_p = []
best_p = 0

for i in range(epochs):
    print("epoch: ",i)
    s = 0
    train_data_ = train_data.sample(frac=1)
    for bid in range(len(train_data_) // batch_size):
        if (bid % 1000 == 0):
          print("iteration: ",i, ", batch: ", bid)
        data = train_data_[bid * batch_size : (bid + 1) * batch_size]
        optimizer.zero_grad()
        
        loss = neu_mf.loss(data, loss_fn)
        loss.backward()
        optimizer.step()
        s += loss
        
    l.append(s.item()/(len(data) // batch_size))
    scheduler.step(s.item()/(len(data) // batch_size))
    # evaluate precision at 10 of the model
  
    neu_mf.eval()
    with torch.no_grad():
      val = val_data.copy()
      val[label_pred] = (neu_mf.predict(val).cpu().detach().numpy() > 0.5).astype(int)
      val_prec, _ = precision_recall_at_k(val, label_pred=label_pred, threshold=threshold, k=k)
      val_prec = sum(prec for prec in val_prec.values()) / len(val_prec)
      train = train_data_.copy()
      train[label_pred] = (neu_mf.predict(train).cpu().detach().numpy() > 0.5).astype(int)
      train_prec, _ = precision_recall_at_k(train, label_pred=label_pred, threshold=threshold, k=k)
      train_prec = sum(prec for prec in train_prec.values()) / len(train_prec)

      train_p.append(train_prec)
      val_p.append(val_prec)
    neu_mf.train()
    
    print("Train precision at 5: ", train_prec)
    print("Validation precision at 5: ", val_prec)
    print("Current best validation precision at 5: ", best_p)
    if val_prec > best_p:
      print("Validation precision better than best current precision. Saving model to best_state_dict...")
      best_state_dict = {
           'model_state_dict': neu_mf.state_dict()
           }
      best_p = val_prec

      
    print("Average Loss for the current iteration: ", l[i])
    print("-----------------------------------")
# Out:
# epoch:  0
# iteration:  0 , batch:  0
# iteration:  0 , batch:  1000
# iteration:  0 , batch:  2000
# iteration:  0 , batch:  3000
# Train precision at 5:  0.7343494699885343
# Validation precision at 5:  0.6956091193482501
# Current best validation precision at 5:  0
# Validation precision better than best current precision. Saving model to best_state_dict...
# Average Loss for the current iteration:  1998.7685546875
# -----------------------------------
# epoch:  1
# iteration:  1 , batch:  0
# iteration:  1 , batch:  1000
# iteration:  1 , batch:  2000
# iteration:  1 , batch:  3000
# Train precision at 5:  0.7367238313865913
# Validation precision at 5:  0.70265343325908
# Current best validation precision at 5:  0.6956091193482501
# Validation precision better than best current precision. Saving model to best_state_dict...
# Average Loss for the current iteration:  2063.92041015625
# -----------------------------------
# epoch:  2
# iteration:  2 , batch:  0
# iteration:  2 , batch:  1000
# iteration:  2 , batch:  2000
# iteration:  2 , batch:  3000
# Train precision at 5:  0.7376240631962822
# Validation precision at 5:  0.7055859383791495
# Current best validation precision at 5:  0.70265343325908
# Validation precision better than best current precision. Saving model to best_state_dict...
# Average Loss for the current iteration:  2068.951171875
# -----------------------------------
# epoch:  3
# iteration:  3 , batch:  0
# iteration:  3 , batch:  1000
# iteration:  3 , batch:  2000
# iteration:  3 , batch:  3000
# Train precision at 5:  0.7320178696014308
# Validation precision at 5:  0.7052224697859868
# Current best validation precision at 5:  0.7055859383791495
# Average Loss for the current iteration:  2065.959716796875
# -----------------------------------
# epoch:  4
# iteration:  4 , batch:  0
# iteration:  4 , batch:  1000
# iteration:  4 , batch:  2000
# iteration:  4 , batch:  3000
# Epoch     5: reducing learning rate of group 0 to 5.0000e-04.
# Train precision at 5:  0.7396484594783255
# Validation precision at 5:  0.7065007989557469
# Current best validation precision at 5:  0.7055859383791495
# Validation precision better than best current precision. Saving model to best_state_dict...
# Average Loss for the current iteration:  2072.084716796875
# -----------------------------------
# epoch:  5
# iteration:  5 , batch:  0
# iteration:  5 , batch:  1000
# iteration:  5 , batch:  2000
# iteration:  5 , batch:  3000
# Train precision at 5:  0.7478765782189014
# Validation precision at 5:  0.7071590934665831
# Current best validation precision at 5:  0.7065007989557469
# Validation precision better than best current precision. Saving model to best_state_dict...
# Average Loss for the current iteration:  2045.024169921875
# -----------------------------------
# epoch:  6
# iteration:  6 , batch:  0
# iteration:  6 , batch:  1000
# iteration:  6 , batch:  2000
# iteration:  6 , batch:  3000
# Train precision at 5:  0.7410663245785878
# Validation precision at 5:  0.7069869241329798
# Current best validation precision at 5:  0.7071590934665831
# Average Loss for the current iteration:  2037.7171630859375
# -----------------------------------
# epoch:  7
# iteration:  7 , batch:  0
# iteration:  7 , batch:  1000
# iteration:  7 , batch:  2000
# iteration:  7 , batch:  3000
# Train precision at 5:  0.7394245268156644
# Validation precision at 5:  0.7101894987959568
# Current best validation precision at 5:  0.7071590934665831
# Validation precision better than best current precision. Saving model to best_state_dict...
# Average Loss for the current iteration:  2035.574462890625
# -----------------------------------
# epoch:  8
# iteration:  8 , batch:  0
# iteration:  8 , batch:  1000
# iteration:  8 , batch:  2000
# iteration:  8 , batch:  3000
# Epoch     9: reducing learning rate of group 0 to 2.5000e-04.
# Train precision at 5:  0.7429478090608402
# Validation precision at 5:  0.7101152296716557
# Current best validation precision at 5:  0.7101894987959568
# Average Loss for the current iteration:  2031.903076171875
# -----------------------------------
# epoch:  9
# iteration:  9 , batch:  0
# iteration:  9 , batch:  1000
# iteration:  9 , batch:  2000
# iteration:  9 , batch:  3000
# Train precision at 5:  0.7444523214727878
# Validation precision at 5:  0.7104370625436218
# Current best validation precision at 5:  0.7101894987959568
# Validation precision better than best current precision. Saving model to best_state_dict...
# Average Loss for the current iteration:  1998.9300537109375
# -----------------------------------
# epoch:  10
# iteration:  10 , batch:  0
# iteration:  10 , batch:  1000
# iteration:  10 , batch:  2000
# iteration:  10 , batch:  3000
# Train precision at 5:  0.748454977156624
# Validation precision at 5:  0.7102468885738231
# Current best validation precision at 5:  0.7104370625436218
# Average Loss for the current iteration:  1991.22802734375
# -----------------------------------
# epoch:  11
# iteration:  11 , batch:  0
# iteration:  11 , batch:  1000
# iteration:  11 , batch:  2000
# iteration:  11 , batch:  3000
# Train precision at 5:  0.7543582472486762
# Validation precision at 5:  0.7107183849841495
# Current best validation precision at 5:  0.7104370625436218
# Validation precision better than best current precision. Saving model to best_state_dict...
# Average Loss for the current iteration:  1986.23388671875
# -----------------------------------
# epoch:  12
# iteration:  12 , batch:  0
# iteration:  12 , batch:  1000
# iteration:  12 , batch:  2000
# iteration:  12 , batch:  3000
# Train precision at 5:  0.7558526320527593
# Validation precision at 5:  0.7119505772736637
# Current best validation precision at 5:  0.7107183849841495
# Validation precision better than best current precision. Saving model to best_state_dict...
# Average Loss for the current iteration:  1981.953125
# -----------------------------------
# epoch:  13
# iteration:  13 , batch:  0
# iteration:  13 , batch:  1000
# iteration:  13 , batch:  2000
# iteration:  13 , batch:  3000
# Train precision at 5:  0.7530315306191407
# Validation precision at 5:  0.7097135012265819
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1829.660400390625
# -----------------------------------
# epoch:  50
# iteration:  50 , batch:  0
# iteration:  50 , batch:  1000
# iteration:  50 , batch:  2000
# iteration:  50 , batch:  3000
# Train precision at 5:  0.7997794432066242
# Validation precision at 5:  0.7068372605946192
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1827.0294189453125
# -----------------------------------
# epoch:  51
# iteration:  51 , batch:  0
# iteration:  51 , batch:  1000
# iteration:  51 , batch:  2000
# iteration:  51 , batch:  3000
# Train precision at 5:  0.7988960907433637
# Validation precision at 5:  0.7076350910359578
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1823.3729248046875
# -----------------------------------
# epoch:  52
# iteration:  52 , batch:  0
# iteration:  52 , batch:  1000
# iteration:  52 , batch:  2000
# iteration:  52 , batch:  3000
# Train precision at 5:  0.8036549411473437
# Validation precision at 5:  0.7069666689172629
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1821.1103515625
# -----------------------------------
# epoch:  53
# iteration:  53 , batch:  0
# iteration:  53 , batch:  1000
# iteration:  53 , batch:  2000
# iteration:  53 , batch:  3000
# Train precision at 5:  0.8027153241959769
# Validation precision at 5:  0.7083147660522746
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1818.4678955078125
# -----------------------------------
# epoch:  54
# iteration:  54 , batch:  0
# iteration:  54 , batch:  1000
# iteration:  54 , batch:  2000
# iteration:  54 , batch:  3000
# Train precision at 5:  0.797257668849726
# Validation precision at 5:  0.7053890126707792
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1817.8189697265625
# -----------------------------------
# epoch:  55
# iteration:  55 , batch:  0
# iteration:  55 , batch:  1000
# iteration:  55 , batch:  2000
# iteration:  55 , batch:  3000
# Train precision at 5:  0.7962032723426262
# Validation precision at 5:  0.7085139423401697
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1817.918701171875
# -----------------------------------
# epoch:  56
# iteration:  56 , batch:  0
# iteration:  56 , batch:  1000
# iteration:  56 , batch:  2000
# iteration:  56 , batch:  3000
# Train precision at 5:  0.795206265613393
# Validation precision at 5:  0.7071939774492099
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1817.6263427734375
# -----------------------------------
# epoch:  57
# iteration:  57 , batch:  0
# iteration:  57 , batch:  1000
# iteration:  57 , batch:  2000
# iteration:  57 , batch:  3000
# Train precision at 5:  0.8110964823442001
# Validation precision at 5:  0.7073819008394825
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1814.60693359375
# -----------------------------------
# epoch:  58
# iteration:  58 , batch:  0
# iteration:  58 , batch:  1000
# iteration:  58 , batch:  2000
# iteration:  58 , batch:  3000
# Train precision at 5:  0.8003364616388673
# Validation precision at 5:  0.7074944298156935
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1814.245361328125
# -----------------------------------
# epoch:  59
# iteration:  59 , batch:  0
# iteration:  59 , batch:  1000
# iteration:  59 , batch:  2000
# iteration:  59 , batch:  3000
# Train precision at 5:  0.8003297099002963
# Validation precision at 5:  0.7073031305561345
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1815.1087646484375
# -----------------------------------
# epoch:  60
# iteration:  60 , batch:  0
# iteration:  60 , batch:  1000
# iteration:  60 , batch:  2000
# iteration:  60 , batch:  3000
# Train precision at 5:  0.8070319357234452
# Validation precision at 5:  0.7076407174847682
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1813.327880859375
# -----------------------------------
# epoch:  61
# iteration:  61 , batch:  0
# iteration:  61 , batch:  1000
# iteration:  61 , batch:  2000
# iteration:  61 , batch:  3000
# Epoch    62: reducing learning rate of group 0 to 6.2500e-05.
# Train precision at 5:  0.8035761708639944
# Validation precision at 5:  0.7085184434992178
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1705.080078125
# -----------------------------------
# epoch:  75
# iteration:  75 , batch:  0
# iteration:  75 , batch:  1000
# iteration:  75 , batch:  2000
# iteration:  75 , batch:  3000
# Train precision at 5:  0.828066977246636
# Validation precision at 5:  0.7033342335651589
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1702.5223388671875
# -----------------------------------
# epoch:  76
# iteration:  76 , batch:  0
# iteration:  76 , batch:  1000
# iteration:  76 , batch:  2000
# iteration:  76 , batch:  3000
# Train precision at 5:  0.8174262372560892
# Validation precision at 5:  0.7039486417752737
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1700.7928466796875
# -----------------------------------
# epoch:  77
# iteration:  77 , batch:  0
# iteration:  77 , batch:  1000
# iteration:  77 , batch:  2000
# iteration:  77 , batch:  3000
# Train precision at 5:  0.8406533432358769
# Validation precision at 5:  0.701493259514341
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1698.3494873046875
# -----------------------------------
# epoch:  78
# iteration:  78 , batch:  0
# iteration:  78 , batch:  1000
# iteration:  78 , batch:  2000
# iteration:  78 , batch:  3000
# Train precision at 5:  0.8227814912339885
# Validation precision at 5:  0.7038158575833433
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1697.9189453125
# -----------------------------------
# epoch:  79
# iteration:  79 , batch:  0
# iteration:  79 , batch:  1000
# iteration:  79 , batch:  2000
# iteration:  79 , batch:  3000
# Train precision at 5:  0.8255249476740153
# Validation precision at 5:  0.7022235725699534
# Current best validation precision at 5:  0.7119505772736637
# Average Loss for the current iteration:  1692.4674072265625
# -----------------------------------

# %%
import matplotlib.pyplot as plt

plt.plot(val_p, color='b', label='Validation')
plt.plot(train_p, color='r', label='Training')
plt.vlines(np.argmax(val_p),0.67,1.0, linestyles='dashed', label='Best model')
plt.ylabel('Precision@5')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %%
## n_users=14811
## n_beers=52583
## device:gpu
## hidden_size=150
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
best_model = NeuMF(gmf_model=gmf_model, mlp_model=mlp_model, n_input=30, device=device)
#torch.save(best_state_dict, "/content/drive/MyDrive/CS247/Models/checkpoints/neu_mf.pth")
best_model.load_state_dict(best_state_dict['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
#label_pred = 'pred_y'
best_model.to(device)
best_model.eval()
test_data[label_pred] = (best_model.predict(test_data)>0.5).cpu().detach().numpy().astype(int)
test_data
# Out:
#         user_id  beer_id  review_overall  pred_y
# 0             0     5892             4.0       1
# 1             2     5892             4.0       1
# 2             9     5892             4.0       1
# 3            12     5892             4.0       1
# 4            17     5892             5.0       1
# ...         ...      ...             ...     ...
# 300822    14731    14334             2.5       1
# 300823    14776    42943             4.5       1
# 300824    14780    22042             4.5       1
# 300825    14785    36467             3.5       0
# 300826    14790    46338             2.0       1
#
# [300827 rows x 4 columns]

# %%
#threshold=4
#k=5
test_prec, test_recall = precision_recall_at_k(test_data, label_pred=label_pred, threshold=threshold, k=k)
# Precision and recall can then be averaged over all users
print("precision at 5 for test set: ", sum(prec for prec in test_prec.values()) / len(test_prec))
print("recall at 5 for test set:", sum(rec for rec in test_recall.values()) / len(test_prec))
# Out:
# precision at 5 for test set:  0.6725078249904468
# recall at 5 for test set: 0.5383868821901306

# %%
while true:
  pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3dccbe0c8c02> in <module>()
# ----> 1 while true:
#       2   pass
#
# NameError: name 'true' is not defined
